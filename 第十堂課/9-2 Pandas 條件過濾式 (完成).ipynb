# %% [markdown]
# # 簡訊內容過濾分析

# %%
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/Code-Gym/python-dataset/master/msg.txt', 
                   sep='\t', 
                   names=['status', 'msg'])
display(df)
# Out:
#      status                                                msg
# 0       ham  Go until jurong point, crazy.. Available only ...
# 1       ham                      Ok lar... Joking wif u oni...
# 2      spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3       ham  U dun say so early hor... U c already then say...
# 4       ham  Nah I don't think he goes to usf, he lives aro...
# ...     ...                                                ...
# 5567   spam  This is the 2nd time we have tried 2 contact u...
# 5568    ham               Will ü b going to esplanade fr home?
# 5569    ham  Pity, * was in mood for that. So...any other s...
# 5570    ham  The guy did some bitching but I acted like i'd...
# 5571    ham                         Rofl. Its true to its name
#
# [5572 rows x 2 columns]

# %% [markdown]
# ## startswith, endswith

# %%
df['msg'].str.startswith('a')
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 5567    False
# 5568    False
# 5569    False
# 5570    False
# 5571    False
# Name: msg, Length: 5572, dtype: bool

# %%
df.loc[df['msg'].str.startswith('a')]
# Out:
#      status                                                msg
# 427     ham                        aathi..where are you dear..
# 907    spam  all the lastest from Stereophonics, Marley, Di...
# 1071    ham    alright, I'll make sure the car is back tonight
# 2088    ham  alright babe, justthought id sayhey! how u do...
# 2843    ham                        aathi..where are you dear..
# 2950    ham                at bruce b downs &amp; fletcher now
# 3440    ham  awesome, how do I deal with the gate? Charles ...
# 3471    ham                        aathi..where are you dear..
# 3555    ham                     am up to my eyes in philosophy
# 4249   spam  accordingly. I repeat, just text the word ok o...
# 4424    ham  alright. Thanks for the advice. Enjoy your nig...
# 4881    ham  alright tyler's got a minor crisis and has to ...
# 5448    ham  aight we can pick some up, you open before ton...

# %%
df[df['msg'].str.startswith('a')]
# Out:
#      status                                                msg
# 427     ham                        aathi..where are you dear..
# 907    spam  all the lastest from Stereophonics, Marley, Di...
# 1071    ham    alright, I'll make sure the car is back tonight
# 2088    ham  alright babe, justthought id sayhey! how u do...
# 2843    ham                        aathi..where are you dear..
# 2950    ham                at bruce b downs &amp; fletcher now
# 3440    ham  awesome, how do I deal with the gate? Charles ...
# 3471    ham                        aathi..where are you dear..
# 3555    ham                     am up to my eyes in philosophy
# 4249   spam  accordingly. I repeat, just text the word ok o...
# 4424    ham  alright. Thanks for the advice. Enjoy your nig...
# 4881    ham  alright tyler's got a minor crisis and has to ...
# 5448    ham  aight we can pick some up, you open before ton...

# %% [markdown]
# ## 過濾不是垃圾信的訊息

# %%
ham_df = df[df['status'] == 'ham']

# %% [markdown]
# ## 過濾不是垃圾信的訊息中，包含英文單字「OK」的訊息
# contains( )

# %%
mask = df['msg'].str.contains('OK')
mask
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 5567    False
# 5568    False
# 5569    False
# 5570    False
# 5571    False
# Name: msg, Length: 5572, dtype: bool

# %%
df[mask]
# Out:
#      status                                                msg
# 225    spam  500 New Mobiles from 2004, MUST GO! Txt: NOKIA...
# 457     ham  LOOK AT AMY URE A BEAUTIFUL, INTELLIGENT WOMAN...
# 803    spam  FREE for 1st week! No1 Nokia tone 4 ur mobile ...
# 820     ham  BOO BABE! U ENJOYIN YOURJOB? U SEEMED 2 B GETT...
# 984     ham  LOOK AT THE FUCKIN TIME. WHAT THE FUCK YOU THI...
# 1017   spam  FREE for 1st week! No1 Nokia tone 4 ur mob eve...
# 1048   spam  1000's flirting NOW! Txt GIRL or BLOKE & ur NA...
# 1080    ham  Me too watching surya movie only. . .after 6 p...
# 1207   spam  As a SIM subscriber, you are selected to recei...
# 1221   spam  No. 1 Nokia Tone 4 ur mob every week! Just txt...
# 1303    ham  FRAN I DECIDED 2 GO N E WAY IM COMPLETELY BROK...
# 1375   spam  500 New Mobiles from 2004, MUST GO! Txt: NOKIA...
# 1380   spam  No. 1 Nokia Tone 4 ur mob every week! Just txt...
# 1574   spam  SMS AUCTION - A BRAND NEW Nokia 7250 is up 4 a...
# ...

# %% [markdown]
# ## 處理欄位名稱
# 將欄位名稱改為大寫

# %%
df.columns.str.upper()
# Out:
# Index(['STATUS', 'MSG'], dtype='object')

# %%
df.columns = df.columns.str.upper()
display(df)
# Out:
#      STATUS                                                MSG
# 0       ham  Go until jurong point, crazy.. Available only ...
# 1       ham                      Ok lar... Joking wif u oni...
# 2      spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3       ham  U dun say so early hor... U c already then say...
# 4       ham  Nah I don't think he goes to usf, he lives aro...
# ...     ...                                                ...
# 5567   spam  This is the 2nd time we have tried 2 contact u...
# 5568    ham               Will ü b going to esplanade fr home?
# 5569    ham  Pity, * was in mood for that. So...any other s...
# 5570    ham  The guy did some bitching but I acted like i'd...
# 5571    ham                         Rofl. Its true to its name
#
# [5572 rows x 2 columns]

# %% [markdown]
# ## 課後練習解答

# %%
mask1 = df['MSG'].str.startswith('L')
df[mask & mask1]
# Out:
#     STATUS                                                MSG
# 457    ham  LOOK AT AMY URE A BEAUTIFUL, INTELLIGENT WOMAN...
# 984    ham  LOOK AT THE FUCKIN TIME. WHAT THE FUCK YOU THI...
